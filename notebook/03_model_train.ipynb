# %%
import pandas as pd
import numpy as np
import os
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %%
data_path = '../data/'

cleaned_data = pd.read_csv(os.path.join(data_path, 'cleaned_data.csv'))

cleaned_data.head(3)
# Out:
#                  customer_unique_id                        product_id  \
# 0  861eff4711a542e4b93843c6dd7febb0  a9516a079e37a9c9c36b9b78b10169e8
# 1  290c77bc529b7ac935b93aa66c333dc3  4aa6014eceb682077f9dc4bffebc05b0
# 2  060e732b5b29e8181a18229c7b0b2b5e  bd07b66896d6f1494f5b86251848ced7
#
#    review_score
# 0             4
# 1             5
# 2             5

# %%
item_user_matrix = pd.pivot_table(cleaned_data, index='product_id', columns='customer_unique_id',\
                                  values='review_score').fillna(0)
item_user_matrix.head(3)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14928\608906244.py:1: PerformanceWarning: The following operation may generate 3105806869 cells in the resulting pandas object.
#   item_user_matrix = pd.pivot_table(cleaned_data, index='product_id', columns='customer_unique_id',\
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 item_user_matrix = pd.pivot_table(cleaned_data, index='product_id', columns='customer_unique_id',\
# ----> 2                                   values='review_score').fillna(0)
#       3 item_user_matrix.head(3)
#
# File c:\Users\DELL\Desktop\ecom-recommendation-system-v1\.venv\lib\site-packages\pandas\core\generic.py:7457, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7455         new_data = result._mgr
#    7456     else:
# -> 7457         new_data = self._mgr.fillna(
# ...
