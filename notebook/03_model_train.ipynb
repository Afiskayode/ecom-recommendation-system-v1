# %%
import pandas as pd
import numpy as np
import os
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %%
data_path = '../data/'

df = pd.read_csv(os.path.join(data_path, 'clean_interactions.csv'))

df.head(3)
# Out:
#                  customer_unique_id                        product_id  \
# 0  861eff4711a542e4b93843c6dd7febb0  a9516a079e37a9c9c36b9b78b10169e8
# 1  290c77bc529b7ac935b93aa66c333dc3  4aa6014eceb682077f9dc4bffebc05b0
# 2  060e732b5b29e8181a18229c7b0b2b5e  bd07b66896d6f1494f5b86251848ced7
#
#    review_score
# 0             4
# 1             5
# 2             5

# %%
item_user_matrix = pd.pivot_table(df, index='product_id', columns='customer_unique_id',\
                                  values='review_score').fillna(0)
item_user_matrix.head(3)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8900\2649202781.py:1: PerformanceWarning: The following operation may generate 3105806869 cells in the resulting pandas object.
#   item_user_matrix = pd.pivot_table(df, index='product_id', columns='customer_unique_id',\
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 item_user_matrix = pd.pivot_table(df, index='product_id', columns='customer_unique_id',\
#       2                                   values='review_score').fillna(0)
#       3 item_user_matrix.head(3)
#
# File c:\Users\admin\Desktop\ecom-recommendation-system-v1\.venv\Lib\site-packages\pandas\core\reshape\pivot.py:267, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort, **kwargs)
#     264     table = concat(pieces, keys=keys, axis=1)
# ...
