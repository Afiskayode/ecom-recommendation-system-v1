# %% [markdown]
# ## Data Preparation & Feature Transformation

# %%
import pandas as pd
import os

data_path = "../data/"

# %% [markdown]
# ### Creating clean customers to product interaction dataset

# %%
customers = pd.read_csv(os.path.join(data_path, 'olist_customers_dataset.csv'))
order_items = pd.read_csv(os.path.join(data_path, 'olist_order_items_dataset.csv'))
order_reviews = pd.read_csv(os.path.join(data_path, 'olist_order_reviews_dataset.csv'))
products = pd.read_csv(os.path.join(data_path, 'olist_products_dataset.csv'))
orders = pd.read_csv(os.path.join(data_path, 'olist_orders_dataset.csv'))

merged_data = customers.merge(orders, on='customer_id')
merged_data = merged_data.merge(order_items, on='order_id')
merged_data = merged_data.merge(order_reviews, on='order_id')
merged_data = merged_data.merge(products, on='product_id')

clean_df = merged_data[['customer_unique_id', 'product_id', 'review_score']]

# %% [markdown]
# #### Filling reviews score with 3 where a customer purchased an item but didnt leave a review; we are assuming since they did leave bad review they liked the product

# %%
clean_df['review_score'] = clean_df['review_score'].fillna(3)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11236\3403015799.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['review_score'] = clean_df['review_score'].fillna(3)

# %%
# max_num = 10
df = clean_df['product_id'][clean_df['product_id'].value_counts() > 10]
# clean_df['product_id']
# Out:
# product_id
# aca2eb7d00ea1a7b8ebd4e68314663af     True
# 422879e10f46682990de24d770e7f83d     True
# 99a4788cb24856965c36a24e339b6058     True
# 389d119b48cf3043d311335e499d9c6b     True
# 368c6c730842d78016ad823897a372db     True
#                                     ...
# 234d0c9586a851ff11033aedd13c1837    False
# 28763a4fd1b597a9c4f31a9579e7d1b4    False
# 9682ad2500ae8b2609e6a88eb0cbc5bb    False
# aea06073397f809424f946979354c9f0    False
# bbf975bffd2ae9ee52f513ae5c8a4b27    False
# Name: count, Length: 32789, dtype: bool
